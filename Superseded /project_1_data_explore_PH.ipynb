# %% [markdown]
# Sheet for data exploration. Import cleaned data csv and explore the dataset for insight, outliers,

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("kc_housing_data_cleaned.csv")
df.describe().round(1)
# Out:
#                  id      price  bedrooms  bathrooms  sqft_living   sqft_lot  \
# count  2.142000e+04    21420.0   21420.0    21420.0      21420.0    21420.0
# mean   4.580940e+09   541861.4       3.4        2.1       2083.1    15128.0
# std    2.876761e+09   367556.9       0.9        0.8        918.8    41530.8
# min    1.000102e+06    78000.0       1.0        0.5        370.0      520.0
# 25%    2.123537e+09   324950.0       3.0        1.8       1430.0     5040.0
# 50%    3.904921e+09   450550.0       3.0        2.2       1920.0     7614.0
# 75%    7.308900e+09   645000.0       4.0        2.5       2550.0    10690.5
# max    9.900000e+09  7700000.0      33.0        8.0      13540.0  1651359.0
#
#         floors  waterfront     view  condition  ...  yr_renovated  zipcode  \
# count  21420.0     21420.0  21420.0    21420.0  ...       21420.0  21420.0
# mean       1.5         0.0      0.2        3.4  ...        1973.0  98077.9
# std        0.5         0.1      0.8        0.7  ...          29.0     53.5
# min        1.0         0.0      0.0        1.0  ...        1900.0  98001.0
# 25%        1.0         0.0      0.0        3.0  ...        1954.0  98033.0
# 50%        1.5         0.0      0.0        3.0  ...        1977.0  98065.0
# 75%        2.0         0.0      0.0        4.0  ...        1999.0  98117.0
# max        3.5         1.0      4.0        5.0  ...        2015.0  98199.0
#
#            lat     long  sqft_living15  sqft_lot15  Compounding  Discounting  \
# count  21420.0  21420.0        21420.0     21420.0      21420.0      21420.0
# mean      47.6   -122.2         1988.4     12775.7          1.1          0.9
# std        0.1      0.1          685.5     27345.6          0.0          0.0
# min       47.2   -122.5          399.0       651.0          1.0          0.9
# 25%       47.5   -122.3         1490.0      5100.0          1.1          0.9
# 50%       47.6   -122.2         1840.0      7620.0          1.1          0.9
# 75%       47.7   -122.1         2370.0     10086.2          1.1          0.9
# max       47.8   -121.3         6210.0    871200.0          1.1          1.0
#
#        price_dec_15  price_dec_19
# count       21420.0       21420.0
# mean       589077.1      737423.5
# std        399712.7      500211.2
# min         85267.2      106150.8
# 25%        351404.6      442227.0
# 50%        492829.7      613157.1
# 75%        700415.4      877785.6
# max       8464718.0    10478991.1
#
# [8 rows x 24 columns]

# %%
df.head(2)
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5056500260  5/2/2014  440000.0         4       2.25         2160      8119
# 1  4040800810  5/2/2014  420000.0         3       2.25         2000      8030
#
#    floors  waterfront  view  ...  zipcode      lat     long  sqft_living15  \
# 0     1.0         0.0   0.0  ...    98006  47.5443 -122.177           1850
# 1     1.0         0.0   0.0  ...    98008  47.6188 -122.114           2070
#
#    sqft_lot15    date_key  Compounding  Discounting  price_dec_15  \
# 0        9000  2014-05-02     1.109072     0.901654     487991.86
# 1        8250  2014-05-02     1.109072     0.901654     465810.41
#
#    price_dec_19
# 0     598799.49
# 1     571581.33
#
# [2 rows x 26 columns]

# %% [markdown]
# Data exploration starts from this point onwards:

# %%
price = df['price_dec_15']
price.plot.hist(alpha = 1, bins = 1000)

# %%
bedrooms = df['bedrooms']
bedrooms.plot.hist(alpha = 1, bins = 20)

# %%
bedrooms = df['bathrooms']
bedrooms.plot.hist(alpha = 1, bins = 10)

# %%
def get_histogram(column, no_bins):
    histogram = df[column]
    histogram.plot.hist(alpha = 1, bins = no_bins)

# %%
get_histogram('price_dec_15',1000)

# %%
get_histogram('yr_built',20)

# %%
bathrooms = df['bathrooms'].unique()

# %%
hist(df['bathrooms'])

# %%
# for the correlation matrix remove 'price' & remove 'price_dec_19'

df1 = df
del df1['price']
del df1['price_dec_19']
del df1['Compounding']
del df1['Discounting']
del df1['lat']
del df1['long']
del df1['zipcode']

import matplotlib.pyplot as plt
plt.figure(figsize=(19, 15))
plt.matshow(df1.corr())
plt.show()

# %%
import pandas as pd
import numpy as np

corr = df1.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col3 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col5 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col6 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col8 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col9 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col10 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col11 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col12 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col13 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col14 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col2 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col3 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col4 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col6 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col8 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col9 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col10 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col11 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col12 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col13 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col14 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col15 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row1_col16 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col3 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col4 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col5 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col7 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col8 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col9 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col10 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col11 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col12 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col13 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col14 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col15 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row2_col16 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col0 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col1 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col2 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col5 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col7 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_1794971c_3ad6_11ea_b1df_94659c3b7158row3_col8 {
#             background-color:  #89acfd;

# %%
df.head(2)
# Out:
#            id        date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  10/13/2014         3       1.00         1180      5650     1.0
# 1  4036801170  10/13/2014         4       1.75         1760      7300     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0          3      7        1180            0.0      1955
# 1         0.0   0.0          3      7         880          880.0      1956
#
#    yr_renovated  sqft_living15  sqft_lot15    date_key  price_dec_15
# 0        1955.0           1340        5650  2014-10-13     243937.78
# 1        1956.0           1680        7500  2014-10-13     417739.33

# %%
dupes = df[df['id'].duplicated() == True]
len(dupes)
# Out:
# 177

# %% [markdown]
# Calculate the distance to the centre downtown area, using differences in long and lat and trigonometry

# %%
import math

def distance_function(coord1, coord2):
    R = 6372800  # Earth radius in meters
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    
    phi1, phi2 = math.radians(lat1), math.radians(lat2) 
    dphi       = math.radians(lat2 - lat1)
    dlambda    = math.radians(lon2 - lon1)
    
    a = math.sin(dphi/2)**2 + \
        math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    
    return 2*R*math.atan2(math.sqrt(a), math.sqrt(1 - a))/(1000*1.60934)  #Convert code from meters to miles

# %% [markdown]
# https://janakiev.com/blog/gps-points-distance-python/

# %%
seattle_downtown = 47.605,  -122.3344
houses = {
    'house 1': (47.5112,  -122.257),
    'house 2': (47.721,  -122.319),
    
    }

for house, coord in houses.items():
    distance = distance_function(seattle_downtown, coord)
    
    
    print(house, distance)
# Out:
# house 1 7.420144604386407
# house 2 8.04909224580169

# %% [markdown]
# Alternative Measure
#
# Miles per Logitude & Latitude Calculator
# http://www.csgnetwork.com/degreelenllavcalc.html

# %%
print('Latitude is :' + str(df.iloc[1][17]))
print('Londitude is :' + str(df.iloc[1][18]))
# Out:
# Latitude is :2014-05-02
# Londitude is :465810.41
